# %%
library("jupytergis")

# %%
doc <- GISDocument$new("france_hiking.jGIS")
doc

# %%
google_layer <- doc$add_raster_layer(
    url = "https://tile.openstreetmap.org/{z}/{x}/{y}.png",
    attribution = "Google",
)

# %%
geotiff_layer <- doc$add_geotiff_layer(
    url="https://eoresults.esa.int/d/FCM-AGB-100m/2023/01/01/FCM-AGB-100m-2023/FCM_Europe_demo_2023_AGB.tif",
    min=0,
    max=240
    )
